# %%
#Date: 9/15/2020 
#Author: Maggie Bao
#Description: 28 ternary-input binary-output one-variable reversible circuit kernels.

# %%
from qiskit import QuantumCircuit

# %%
#Equation 5

# %%
#[1, A1, A2] 1
c = QuantumCircuit(3)
c.cx(1,0)
c.cx(2,0)
c.draw(output='mpl')

# %%
#[A0, 1, A2] 2
c = QuantumCircuit(3)
c.cx(0,1)
c.cx(2,1)
c.draw(output='mpl')

# %%
#[A0, A1, 1] 3
c = QuantumCircuit(3)
c.cx(0,2)
c.cx(1,2)
c.draw(output='mpl')

# %%
#Equation 6

# %%
#[1, A01, 02] 4
c = QuantumCircuit(3)
c.cx(0,1)
c.cx(0,2)
c.cx(1,0)
c.cx(2,0)
c.draw(output='mpl')

# %%
#[A01, 1, A12] 5
c = QuantumCircuit(3)
c.cx(1,0)
c.cx(1,2)
c.cx(0,1)
c.cx(2,1)
c.draw(output='mpl')

# %%
#[A02, A12, 1] 6
c = QuantumCircuit(3)
c.cx(2,0)
c.cx(2,1)
c.cx(0,2)
c.cx(1,2)
c.draw(output='mpl')

# %%
#Equation 7

# %%
#[A0, A01, 1] 7
c = QuantumCircuit(3)
c.cx(1,2)
c.cx(0,2)
c.cx(0,1)
c.draw(output='mpl')

# %%
#[A01, A1, 1] 8
c = QuantumCircuit(3)
c.cx(1,2)
c.cx(0,2)
c.cx(1,0)
c.draw(output='mpl')

# %%
#[A0, 1, A02] 9
c = QuantumCircuit(3)
c.cx(0,1)
c.cx(2,1)
c.cx(0,2)
c.draw(output='mpl')

# %%
#[A02, 1, A2] 10
c = QuantumCircuit(3)
c.cx(0,1)
c.cx(2,1)
c.cx(2,0)
c.draw(output='mpl')

# %%
#[1, A1, A12] 11
c = QuantumCircuit(3)
c.cx(1,0)
c.cx(2,0)
c.cx(1,2)
c.draw(output='mpl')

# %%
#[1, A12, A2] 12
c = QuantumCircuit(3)
c.cx(1,0)
c.cx(2,0)
c.cx(2,1)
c.draw(output='mpl')

# %%
#Equation 8

# %%
#[A0, A1, A02] 13
c = QuantumCircuit(3)
c.cx(0,2)
c.draw(output='mpl')

# %%
#[A0, A1, A12] 14
c = QuantumCircuit(3)
c.cx(1,2)
c.draw(output='mpl')

# %%
#[A01, A1, A2] 15
c = QuantumCircuit(3)
c.cx(1,0)
c.draw(output='mpl')

# %%
#[A02, A1, A2] 16
c = QuantumCircuit(3)
c.cx(2,0)
c.draw(output='mpl')

# %%
#[A0, A01, A2] 17
c = QuantumCircuit(3)
c.cx(0,1)
c.draw(output='mpl')

# %%
#[A0, A02, A2] 18
c = QuantumCircuit(3)
c.cx(2,1)
c.draw(output='mpl')

# %%
#Equation 9

# %%
#[A0, A01, A02] 19
c = QuantumCircuit(3)
c.cx(0,1)
c.cx(0,2)
c.draw(output='mpl')

# %%
#[A01, A1, A02] 20
c = QuantumCircuit(3)
c.cx(0,2)
c.cx(1,0)
c.draw(output='mpl')

# %%
#[A02, A01, A2] 21
c = QuantumCircuit(3)
c.cx(0,1)
c.cx(2,0)
c.draw(output='mpl')

# %%
#[A0, A12, A02] 22
c = QuantumCircuit(3)
c.cx(2,1)
c.cx(0,2)
c.draw(output='mpl')

# %%
#[A02, A1, A12] 23
c = QuantumCircuit(3)
c.cx(2,0)
c.cx(1,2)
c.draw(output='mpl')

# %%
#[A02, A1, A12] 24
c = QuantumCircuit(3)
c.cx(2,1)
c.cx(2,0)
c.draw(output='mpl')

# %%
#[A0, A02, A2] 25
c = QuantumCircuit(3)
c.cx(1,2)
c.cx(0,1)
c.draw(output='mpl')

# %%
#[A01, A1, A12] 26
c = QuantumCircuit(3)
c.cx(1,0)
c.cx(1,2)
c.draw(output='mpl')

# %%
#[A01, A12, A2] 27
c = QuantumCircuit(3)
c.cx(1,0)
c.cx(2,1)
c.draw(output='mpl')

# %%
#Equation 10

# %%
#[A0, A1, A2] "Ternary Shannon" 28
c = QuantumCircuit(3)
c.draw(output='mpl')

# %%
#[A01, A12, A02] 29
c = QuantumCircuit(3)
c.cx(1,0)
c.cx(2,1)
c.draw(output='mpl')

# %%
c= QuantumCircuit(3)
c.cx(0,1)
c.cx(2,1)
c.draw(output='mpl')
